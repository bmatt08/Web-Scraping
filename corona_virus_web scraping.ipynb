# %%
import requests
from bs4 import BeautifulSoup

# %%
#URL for scraping data

url = 'https://www.worldometers.info/coronavirus/countries-where-coronavirus-has-spread/'

# %%
#get URL html

page = requests.get(url)
soup = BeautifulSoup(page.text, 'html.parser')

data = []

# %%
#Scraping every element in the url's table

data_iterator = iter(soup.find_all('td'))

# %%
#Loop will keep repeating until there is data available in the iterator

while True:
    try:
        country = next(data_iterator).text
        confirmed = next(data_iterator).text
        deaths = next(data_iterator).text
        continent = next(data_iterator).text
 
        data.append((
            country,
            int(confirmed.replace(',', '', 26723249)),
            int(deaths.replace(',', '', 196487)),
            continent
        ))
 
    except StopIteration:
        break

# %%
#Sorting the data by the number of confirmed cases

data.sort(key = lambda row: row[1], reverse = True)

# %%
import texttable as tt
table = tt.Texttable()

# %%
table.add_rows([(None, None, None, None)] + data)

table.set_cols_align(('c', 'c', 'c', 'c'))
table.header((' Country ', ' Number of Cases ', ' Deaths ', ' Continent '))

# %%
print(table.draw())
# Out:
# +---------------------------+-------------------+----------+-------------------+
# |          Country          |  Number of Cases  |  Deaths  |     Continent     |
# +===========================+===================+==========+===================+
# |       United States       |     1.118e+08     | 1219487  |   North America   |
# +---------------------------+-------------------+----------+-------------------+
# |           India           |     45035393      |  533570  |       Asia        |
# +---------------------------+-------------------+----------+-------------------+
# |          France           |     40138560      |  167642  |      Europe       |
# +---------------------------+-------------------+----------+-------------------+
# |          Germany          |     38828995      |  183027  |      Europe       |
# +---------------------------+-------------------+----------+-------------------+
# |          Brazil           |     38743918      |  711380  |   South America   |
# ...
